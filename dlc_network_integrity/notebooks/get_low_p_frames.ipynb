# %%
# !pip install tables
import os
os.getcwd()
os.chdir('..')
# Out:
# ...
#      |████████████████████████████████| 4.3MB 3.3MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 163kB 30.0MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from dlc_network_integrity.models.rawdlc import Rawdlc
print(os.getcwd())
filename = '/home/jovyan/work/dlc_network_integrity/data/7061_20190830_CC1_02_R01DLC_resnet50_leftPP_CenterFeb13shuffle1_950000.h5'
sess = Rawdlc(filename)

sess.bodyparts
# Out:
# /home/jovyan
# {'leftPaw', 'nose', 'pellet', 'rightPaw'}

# %%
nose = 'nose'
leftpaw = 'leftPaw'
pellet = 'pellet'
rightpaw = 'rightPaw'

# %%
nose_data = sess.get_loc(nose)
nose_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 960 entries, 0 to 959
# Data columns (total 3 columns):
# x             960 non-null float64
# y             960 non-null float64
# likelihood    960 non-null float64
# dtypes: float64(3)
# memory usage: 30.0 KB

# %%
nose_data.iloc[:,-1].hist()

# %%
low_p_95 = nose_data.loc[nose_data['likelihood'] < 0.95]

# %%
low_p_95.columns
# Out:
# Index(['x', 'y', 'likelihood'], dtype='object', name='coords')

# %%
frame_nums = low_p_95.index
# This is the original frame number, how fucking convenient is that?!
for val in frame_nums:
    # do something to each frame
    pass
