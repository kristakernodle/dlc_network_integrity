# %%
from work.models.dlc_out import dlc_out_file

filename = '/home/jovyan/work/data/7061_20190830_CC1_02_R01DLC_resnet50_leftPP_CenterFeb13shuffle1_950000.h5'
dlc_out_obj = dlc_out_file(filename)

data = pd.DataFrame.from_dict(dlc_out_obj.data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-11b5d5da577c> in <module>
# ----> 1 from work.models.dlc_out import dlc_out_file
#       2
#       3 filename = '/home/jovyan/work/data/7061_20190830_CC1_02_R01DLC_resnet50_leftPP_CenterFeb13shuffle1_950000.h5'
#       4 dlc_out_obj = dlc_out_file(filename)
#       5
#
# ImportError: cannot import name 'dlc_out_file' from 'work.models.dlc_out' (/home/jovyan/work/models/dlc_out.py)

# %%
dlc_out_obj.bodyparts
dlc_out_obj.network
dlc_out_obj.filepath
# Out:
# '/home/jovyan/work/data/7061_20190830_CC1_02_R01DLC_resnet50_leftPP_CenterFeb13shuffle1_950000.h5'

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
data = pd.DataFrame.from_dict(dlc_out_obj.data)

# %%
sb.distplot(data['nose'],kde = False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7e48e715a527> in <module>
# ----> 1 sb.distplot(data['nose'],kde = False)
#       2 plt.show()
#
# NameError: name 'data' is not defined
