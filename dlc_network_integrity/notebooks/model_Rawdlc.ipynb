# %%
# !pip install easydict
# !pip install tables
# !pip install ruamel.yaml
import os
import pandas as pd
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
#      |████████████████████████████████| 4.3MB 3.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 163kB 25.2MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
filename = '/home/jovyan/work/7061_20190830_CC1_02_R01DLC_resnet50_leftPP_CenterFeb13shuffle1_950000.h5'

with open(filename, 'rb') as f:
    data = pd.read_hdf(filename)

cols = data.columns[0][0]
print(cols)
# Out:
# DLC_resnet50_leftPP_CenterFeb13shuffle1_950000

# %%
leftpaw_loc = pd.DataFrame(zip(
    data[('DLC_resnet50_leftPP_CenterFeb13shuffle1_950000', 'leftPaw', 'x')].values, 
    data[('DLC_resnet50_leftPP_CenterFeb13shuffle1_950000', 'leftPaw', 'y')].values ))

leftpaw_p = pd.DataFrame(dat b a[('DLC_resnet50_leftPP_CenterFeb13shuffle1_950000', 'leftPaw', 'likelihood')].values)

leftpaw_p.plot.hist()

# %%
print(set([col[1] for col in data.columns]))
# Out:
# {'rightPaw', 'leftPaw', 'nose', 'pellet'}
