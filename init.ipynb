# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then pip install $(sed '/jedi/d;/jupyter/d;' ./requirements.txt)
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#     then pip install  $(sed '/jupyter/d' .deepnote/requirements.txt)
#     else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (19.3.0)
# Requirement already satisfied: backcall==0.1.0 in /opt/venv/lib/python3.7/site-packages (0.1.0)
# Requirement already satisfied: bleach==3.1.0 in /opt/venv/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: certifi==2019.11.28 in /opt/venv/lib/python3.7/site-packages (2019.11.28)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (0.10.0)
# Requirement already satisfied: decorator==4.4.1 in /opt/venv/lib/python3.7/site-packages (4.4.1)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/venv/lib/python3.7/site-packages (0.6.2)
# Collecting easydict==1.9
#   Downloading https://files.pythonhosted.org/packages/4c/c5/5757886c4f538c1b3f95f6745499a24bffa389a805dee92d093e2d9ba7db/easydict-1.9.tar.gz
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (0.3)
# Requirement already satisfied: idna==2.8 in /opt/venv/lib/python3.7/site-packages (2.8)
# Requirement already satisfied: importlib-metadata==1.3.0 in /opt/venv/lib/python3.7/site-packages (1.3.0)
# Requirement already satisfied: ipykernel==5.1.3 in /opt/venv/lib/python3.7/site-packages (5.1.3)
# Requirement already satisfied: ipython==7.11.1 in /opt/venv/lib/python3.7/site-packages (7.11.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (7.5.1)
# Requirement already satisfied: jedi==0.15.2 in /opt/venv/lib/python3.7/site-packages (0.15.2)
# Requirement already satisfied: Jinja2==2.10.3 in /opt/venv/lib/python3.7/site-packages (2.10.3)
# Requirement already satisfied: joblib==0.14.1 in /opt/venv/lib/python3.7/site-packages (0.14.1)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (3.2.0)
# Requirement already satisfied: kiwisolver==1.1.0 in /opt/venv/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: matplotlib==3.1.2 in /opt/venv/lib/python3.7/site-packages (3.1.2)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (0.8.4)
# Requirement already satisfied: more-itertools==8.0.2 in /opt/venv/lib/python3.7/site-packages (8.0.2)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (5.6.1)
# Requirement already satisfied: nbformat==5.0.3 in /opt/venv/lib/python3.7/site-packages (5.0.3)
# Requirement already satisfied: notebook==7.0.0.dev0 in /opt/venv/lib/python3.7/site-packages (7.0.0.dev0)
# Collecting numexpr==2.7.1
#   Downloading https://files.pythonhosted.org/packages/c5/de/3811c7ce8612b4a27bfbf81a779c5970a31a038e32dc6a979e7f2867f56d/numexpr-2.7.1-cp37-cp37m-manylinux1_x86_64.whl (162kB)
# Requirement already satisfied: numpy==1.18.1 in /opt/venv/lib/python3.7/site-packages (1.18.1)
# Requirement already satisfied: pandas==0.25.0 in /opt/venv/lib/python3.7/site-packages (0.25.0)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (1.4.2)
# Requirement already satisfied: parso==0.5.2 in /opt/venv/lib/python3.7/site-packages (0.5.2)
# Requirement already satisfied: pexpect==4.7.0 in /opt/venv/lib/python3.7/site-packages (4.7.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (0.7.5)
# Requirement already satisfied: pipreqs==0.4.8 in /opt/venv/lib/python3.7/site-packages (0.4.8)
# Requirement already satisfied: pluggy==0.13.1 in /opt/venv/lib/python3.7/site-packages/pluggy-0.13.1-py3.7.egg (0.13.1)
# Requirement already satisfied: prometheus-client==0.7.1 in /opt/venv/lib/python3.7/site-packages (0.7.1)
# Requirement already satisfied: prompt-toolkit==3.0.2 in /opt/venv/lib/python3.7/site-packages (3.0.2)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (0.6.0)
# Requirement already satisfied: Pygments==2.5.2 in /opt/venv/lib/python3.7/site-packages (2.5.2)
# Requirement already satisfied: pyparsing==2.4.6 in /opt/venv/lib/python3.7/site-packages (2.4.6)
# Requirement already satisfied: pyrsistent==0.15.7 in /opt/venv/lib/python3.7/site-packages (0.15.7)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (0.3.4)
# Requirement already satisfied: python-language-server==0.30.0+5.ge3b6920 in /opt/venv/lib/python3.7/site-packages/python_language_server-0.30.0+5.ge3b6920-py3.7.egg (0.30.0+5.ge3b6920)
# Requirement already satisfied: pytz==2019.3 in /opt/venv/lib/python3.7/site-packages (2019.3)
# Requirement already satisfied: pyzmq==18.1.1 in /opt/venv/lib/python3.7/site-packages (18.1.1)
# Requirement already satisfied: requests==2.22.0 in /opt/venv/lib/python3.7/site-packages (2.22.0)
# Collecting ruamel.yaml==0.16.10
#   Downloading https://files.pythonhosted.org/packages/a6/92/59af3e38227b9cc14520bf1e59516d99ceca53e3b8448094248171e9432b/ruamel.yaml-0.16.10-py2.py3-none-any.whl (111kB)
# Collecting ruamel.yaml.clib==0.2.0
#   Downloading https://files.pythonhosted.org/packages/40/80/da16b691d5e259dd9919a10628e541fca321cb4b078fbb88e1c7c22aa42d/ruamel.yaml.clib-0.2.0-cp37-cp37m-manylinux1_x86_64.whl (547kB)
# Requirement already satisfied: scikit-learn==0.22.1 in /opt/venv/lib/python3.7/site-packages (0.22.1)
# Requirement already satisfied: scipy==1.4.1 in /opt/venv/lib/python3.7/site-packages (1.4.1)
# Collecting seaborn==0.10.1
#   Downloading https://files.pythonhosted.org/packages/c7/e6/54aaaafd0b87f51dfba92ba73da94151aa3bc179e5fe88fc5dfb3038e860/seaborn-0.10.1-py3-none-any.whl (215kB)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (1.5.0)
# Requirement already satisfied: six==1.13.0 in /opt/venv/lib/python3.7/site-packages (1.13.0)
# Collecting tables==3.6.1
#   Downloading https://files.pythonhosted.org/packages/0f/cb/4097be890a773af95343389faa8c283b0d9ff606f144227a548461dcbdd5/tables-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (4.3MB)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (0.4.4)
# Requirement already satisfied: tornado==6.0.3 in /opt/venv/lib/python3.7/site-packages (6.0.3)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (1.35)
# Requirement already satisfied: urllib3==1.25.7 in /opt/venv/lib/python3.7/site-packages (1.25.7)
# Requirement already satisfied: wcwidth==0.1.8 in /opt/venv/lib/python3.7/site-packages (0.1.8)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (3.5.1)
# Requirement already satisfied: yarg==0.1.9 in /opt/venv/lib/python3.7/site-packages (0.1.9)
# Requirement already satisfied: zipp==0.6.0 in /opt/venv/lib/python3.7/site-packages (0.6.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.1.3) (5.3.4)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.11.1) (44.0.0)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1) (4.6.1)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py): started
#   Building wheel for easydict (setup.py): finished with status 'done'
#   Created wheel for easydict: filename=easydict-1.9-cp37-none-any.whl size=6350 sha256=2715dd0c2060750d65a10567e9d5b00189c7bc0ecfad31202683bfc77a8f3f90
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9a/88/ec/085d92753646b0eda1b7df49c7afe51a6ecc496556d3012e2e
# Successfully built easydict
# Installing collected packages: easydict, numexpr, ruamel.yaml.clib, ruamel.yaml, seaborn, tables
# Successfully installed easydict-1.9 numexpr-2.7.1 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 seaborn-0.10.1 tables-3.6.1
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
